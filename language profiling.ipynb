# %% [markdown]
# # Creation of Language Training Profiles

# %% [markdown]
# ## 1. Required Imports

# %%
import nltk
from nltk.tokenize import word_tokenize
import pandas as pd

# %% [markdown]
# ## 2. Read Wili-2018 Dataset and filter it for 37 European Languages

# %%
data = pd.read_csv('/Users/tofii/Downloads/Language Detection/wili-2018/x_train.txt', sep='\r\n', header=None, engine='python')
res = pd.read_csv('/Users/tofii/Downloads/Language Detection/wili-2018/y_train.txt', sep='\r\n', header=None, engine='python')
langs = ['eng','deu','fra','ita','spa']
#'nld','swe']
#,'tur','lat','dan','por','fra','bos','bul','gle','be-tarask','spa','isl','cym','srp','ita','fin','cat','ron','ces','rus','lit','sqi','slk','ukr','hrv','eng','mlt','hye','nno','hun','deu','mwl','pol','ell','ltz']
data['1'] = res
data.columns = ['text', 'lang']
data = data[data['lang'].isin(langs)].reset_index(drop=True)
data.head()
# Out:
#                                                 text lang
# 0  Association de recherche et de sauvegarde de l...  fra
# 1  En Navidad de 1974, poco después de que interp...  spa
# 2  La chirurgie comprenant principalement l'ablat...  fra
# 3  Dès les années 1920, les communes voisines d'A...  fra
# 4  L'ufficio progettazione, sembra ormai certo, s...  ita

# %% [markdown]
# ## 3. Print filtered Lang Samples and Shape of Dataframe

# %%
print(data.head())
data.shape
# Out:
#                                                 text lang
# 0  Association de recherche et de sauvegarde de l...  fra
# 1  En Navidad de 1974, poco después de que interp...  spa
# 2  La chirurgie comprenant principalement l'ablat...  fra
# 3  Dès les années 1920, les communes voisines d'A...  fra
# 4  L'ufficio progettazione, sembra ormai certo, s...  ita
# (2500, 2)

# %% [markdown]
# ## 4. Preprocess Lang Data(Remove punctuations and digits)

# %%
data['text'] = data['text'].str.replace(r'[^\w\s]+', '')
data['text'] = data['text'].str.replace(r'[\d]+', '')
data['text'] = data['text'].astype(str).str.lower()
data.shape
# Out:
# (2500, 2)

# %% [markdown]
# ## 4. Tokenize Lang Data to Prepare Lang Profiles

# %%
#data = data.groupby('lang')['text'].apply(' '.join).reset_index()
data['text'] = data.text.apply(word_tokenize)
data.shape
# Out:
# (2500, 2)

# %% [markdown]
# ## 5. Function to Create N-GRAMS

# %%
def word2ngrams(text, n=3):
  """ Convert word into character ngrams. """
  return [text[i:i+n] for i in range(len(text)-n+1)]

# %% [markdown]
# ## 6. Generate Lang Profiles using Mono, Bi and Tri GRAMS

# %%
ngrams = []
data['ngrams'] = ''
for lang in data.text:
    lang_ngram = []
    for word in lang:
        lang_ngram = lang_ngram + word2ngrams(word,1) + word2ngrams(word,2) + word2ngrams(word, 3)
    lang_ngram = sorted(list(set(lang_ngram)), key=len)
    ngrams.append(lang_ngram)

for i in range(len(ngrams)):
    data.at[i, 'ngrams'] = ngrams[i]
data.shape
# Out:
# (2500, 3)

# %%
data.head()
# Out:
#                                                 text lang  \
# 0  [association, de, recherche, et, de, sauvegard...  fra
# 1  [en, navidad, de, poco, después, de, que, inte...  spa
# 2  [la, chirurgie, comprenant, principalement, la...  fra
# 3  [dès, les, années, les, communes, voisines, da...  fra
# 4  [lufficio, progettazione, sembra, ormai, certo...  ita
#
#                                               ngrams
# 0  [b, y, e, é, t, m, v, s, r, l, p, u, g, d, h, ...
# 1  [b, y, e, á, é, t, m, v, s, r, p, l, u, q, g, ...
# 2  [b, e, x, é, t, m, v, s, r, l, p, u, g, d, h, ...
# 3  [x, r, l, p, g, e, v, s, u, m, ê, q, n, è, à, ...
# 4  [b, e, t, m, v, s, r, l, p, u, g, d, h, i, o, ...

# %% [markdown]
# ## 7. Write Generated Lang Profiles in JSON

# %%
data.to_json('/Users/tofii/Downloads/Language Detection/wili-2018/lang_profiles.json', orient='values')

# %% [markdown]
# # Detect Language using Test Language Profiles

# %% [markdown]
# ## 1. Load Test Data

# %%
test_data = pd.read_csv('/Users/tofii/Downloads/Language Detection/wili-2018/x_test.txt', sep='\r\n', header=None, engine='python')
test_res = pd.read_csv('/Users/tofii/Downloads/Language Detection/wili-2018/y_test.txt', sep='\r\n', header=None, engine='python')
test_langs = ['nld']
    #'swe','nld','tur','lat','dan','por','fra','bos','bul','gle','be-tarask','spa','isl','cym','srp','ita','fin','cat','ron','ces','rus','lit','sqi','slk','ukr','hrv','eng','mlt','hye','nno','hun','deu','mwl','pol','ell','ltz']
test_data['1'] = test_res
test_data.columns = ['text', 'lang']
test_data = test_data[test_data['lang'].isin(langs)].reset_index(drop=True)
test_data.head()
# Out:
#                                                 text lang
# 0  La ciudad de San Cristóbal es sede del Hospita...  spa
# 1  Les supporters de l'ASM Clermont Auvergne ont ...  fra
# 2  Anton (or Antonius) Maria Schyrleus (also Schy...  eng
# 3  Ralph Staub est un réalisateur, producteur, sc...  fra
# 4  Spesso usata quale motto o incitazione, ha il ...  ita

# %% [markdown]
# ## 2. Print filtered Lang Test Samples and Shape of Dataframe

# %%
print(test_data.head())
test_data.shape
# Out:
#                                                 text lang
# 0  La ciudad de San Cristóbal es sede del Hospita...  spa
# 1  Les supporters de l'ASM Clermont Auvergne ont ...  fra
# 2  Anton (or Antonius) Maria Schyrleus (also Schy...  eng
# 3  Ralph Staub est un réalisateur, producteur, sc...  fra
# 4  Spesso usata quale motto o incitazione, ha il ...  ita
# (2500, 2)

# %% [markdown]
# ## 3. Preprocess Test Lang Data(Remove punctuations and digits)

# %%
test_data['text'] = test_data['text'].str.replace(r'[^\w\s]+', '')
test_data['text'] = test_data['text'].str.replace(r'[\d]+', '')
test_data['text'] = test_data['text'].astype(str).str.lower()
test_data.head()
# Out:
#                                                 text lang
# 0  la ciudad de san cristóbal es sede del hospita...  spa
# 1  les supporters de lasm clermont auvergne ont r...  fra
# 2  anton or antonius maria schyrleus also schyrl ...  eng
# 3  ralph staub est un réalisateur producteur scén...  fra
# 4  spesso usata quale motto o incitazione ha il s...  ita

# %% [markdown]
# ## 4. Tokenize Test Lang Data to Prepare Lang Profiles

# %%
test_data['text'] = test_data.text.apply(word_tokenize)
test_data.head()
# Out:
#                                                 text lang
# 0  [la, ciudad, de, san, cristóbal, es, sede, del...  spa
# 1  [les, supporters, de, lasm, clermont, auvergne...  fra
# 2  [anton, or, antonius, maria, schyrleus, also, ...  eng
# 3  [ralph, staub, est, un, réalisateur, producteu...  fra
# 4  [spesso, usata, quale, motto, o, incitazione, ...  ita

# %% [markdown]
# ## 5. Generate Test Lang Profiles using Mono, Bi and Tri GRAMS

# %%
ngrams = []
test_data['ngrams'] = ''
for lang in test_data.text:
    lang_ngram = []
    for word in lang:
        lang_ngram = lang_ngram + word2ngrams(word,1) + word2ngrams(word,2) + word2ngrams(word, 3)
    lang_ngram = sorted(list(set(lang_ngram)), key=len)
    ngrams.append(lang_ngram)
#print(ngrams)
for i in range(len(ngrams)):
    test_data.at[i, 'ngrams'] = ngrams[i]
test_data.head()
# Out:
#                                                 text lang  \
# 0  [la, ciudad, de, san, cristóbal, es, sede, del...  spa
# 1  [les, supporters, de, lasm, clermont, auvergne...  fra
# 2  [anton, or, antonius, maria, schyrleus, also, ...  eng
# 3  [ralph, staub, est, un, réalisateur, producteu...  fra
# 4  [spesso, usata, quale, motto, o, incitazione, ...  ita
#
#                                               ngrams
# 0  [b, e, á, t, m, v, s, r, l, p, u, g, d, h, i, ...
# 1  [e, x, é, t, m, v, s, ç, r, l, p, u, q, g, d, ...
# 2  [b, y, e, x, t, m, v, z, s, r, l, p, u, š, g, ...
# 3  [b, j, e, é, t, m, s, r, p, l, u, g, d, h, i, ...
# 4  [e, t, m, v, s, r, p, l, u, q, g, d, h, i, o, ...

# %%
test_data.shape
# Out:
# (2500, 3)

# %%
print(data['ngrams'][0])
print(test_data['ngrams'][0])
# Out:
# ['b', 'y', 'e', 'é', 't', 'm', 'v', 's', 'r', 'l', 'p', 'u', 'g', 'd', 'h', 'i', 'o', 'c', 'n', 'f', 'a', 'è', 'ap', 'eg', 'is', 'un', 'oi', 're', 'cl', 'ar', 'ec', 'ra', 'de', 'au', 'as', 'bi', 'oc', 'gr', 'vo', 'hi', 'at', 'he', 'er', 'ns', 'rs', 'ir', 'ph', 'ie', 've', 'ro', 'bl', 'si', 'et', 'rc', 'so', 'li', 'du', 'og', 'ia', 'sa', 'mo', 'nc', 'ga', 'la', 'ss', 'io', 'lh', 'on', 'st', 'mé', 'en', 'hr', 'iè', 'ye', 'ci', 'fr', 'rf', 'an', 'ib', 'sy', 'sh', 'ti', 'ém', 'ch', 'rd', 'nf', 'da', 'ce', 'to', 'le', 'èc', 'uv', 'rec', 'hrf', 'auv', 'hie', 'nfr', 'tio', 'che', 'anc', 'cia', 'lhi', 'ion', 'erc', 'oir', 'sso', 'dun', 'rsh', 'ech', 'rch', 'yen', 'soc', 'her', 'ass', 'siè', 'lio', 'ega', 'rap', 'gar', 'ssy', 'moi', 'toi', 'ois', 'ècl', 'ard', 'ist', 'cle', 'ars', 'his', 'bli', 'nce', 'oci', 'mém', 'voi', 'sye', 'ans', 'aph', 'ire', 'sau', 'émo', 'phi', 'dan', 'fra', 'uve', 'bib', 'iog', 'sto', 'ran', 'ati', 'ogr', 'rde', 'gra', 'iat', 'ièc', 'ibl', 'enf', 'roi', 'veg', 'shr', 'iss']
# ['b', 'e', 'á', 't', 'm', 'v', 's', 'r', 'l', 'p', 'u', 'g', 'd', 'h', 'i', 'o', 'c', 'n', 'a', 'ó', 'ic', 'is', 'rv', 'al', 'má', 'mi', 're', 'ri', 'cr', 'ar', 'in', 'nd', 'ra', 'iu', 'de', 'as', 'it', 'nt', 'oc', 'ób', 'co', 'el', 'rt', 'oe', 'er', 'ta', 'br', 'ad', 'ud', 'ás', 'ma', 'ro', 'tó', 'vi', 'ne', 'ia', 'sa', 'te', 'pi', 'pr', 'ho', 'mo', 'nc', 'la', 'no', 'io', 'om', 'se', 'st', 'on', 'ca', 'od', 'en', 'es', 'ge', 'sp', 'ci', 'an', 'do', 'na', 'am', 'os', 'ed', 'ba', 'da', 'rn', 'ov', 'ce', 'to', 'em', 'der', 'doc', 'ita', 'tod', 'gen', 'nci', 'com', 'ent', 'cia', 'cen', 'sed', 'odo', 'nte', 'pro', 'mod', 'ici', 'man', 'res', 'emi', 'est', 'dad', 'ern', 'uda', 'spi', 'are', 'isa', 'ama', 'era', 'oce', 'nar', 'vic', 'mas', 'art', 'bri', 'ant', 'ist', 'ris', 'rin', 'más', 'hos', 'rvi', 'iud', 'cam', 'con', 'ene', 'tób', 'inc', 'tem', 'oma', 'rte', 'pit', 'ner', 'del', 'bal', 'cio', 'stó', 'ode', 'ral', 'mis', 'dan', 'pin', 'ios', 'ede', 'ste', 'erv', 'tal', 'ciu', 'rno', 'óba', 'ser', 'oes', 'osp', 'rov', 'cri', 'ovi', 'san', 'ind', 'and', 'vin', 'nda', 'ina']

# %%
data.shape
# Out:
# (2500, 3)

# %%
UB = 0.95
LB = 0.92

for i in range(len(test_data)):
    for j in range(len(data)):
        data.at[j, 'match_rate_lang_'+str(i)] = len(set(test_data.iloc[i]['ngrams']).intersection(data.iloc[j]['ngrams']))/len(data.iloc[j]['ngrams'])
data.head()

# %%
print('Language\tScore')
for i in range(len(test_data)):
    print(data.loc[data['match_rate_lang_'+str(i)].idxmax()]['lang']+'\t'+str(data.loc[data['match_rate_lang_'+str(i)].idxmax()]['match_rate_lang_'+str(i)]))
# Out:
# Language	Score
# nld	0.5915492957746479
# swe	0.9767441860465116
# swe	0.5657894736842105
# swe	0.5664335664335665
# nld	0.7853107344632768
# nld	0.42613636363636365
# nld	0.7810650887573964
# swe	0.8275862068965517
# swe	0.6713286713286714
# swe	0.7045454545454546
# nld	0.42962962962962964
# swe	0.43243243243243246
# swe	0.6063829787234043
# swe	0.7158469945355191
# nld	0.3898305084745763
# swe	0.923469387755102
# swe	0.7784090909090909
# nld	0.6637931034482759
# nld	0.7928994082840237
# swe	0.7954545454545454
# nld	0.5638297872340425
# nld	0.6513761467889908
# nld	0.6190476190476191
# nld	0.562962962962963
# nld	0.6206896551724138
# nld	0.5460526315789473
# swe	0.9678899082568807
# swe	0.45495495495495497
# swe	0.5257142857142857
# swe	0.8026315789473685
# swe	0.8768472906403941
# nld	0.4619289340101523
# swe	0.9906542056074766
# nld	0.7276595744680852
# swe	0.46835443037974683
# nld	0.43783783783783786
# swe	0.5070422535211268
# swe	0.7114093959731543
# swe	0.9736842105263158
# nld	0.6699029126213593
# nld	0.6810344827586207
# swe	0.7738095238095238
# nld	0.6551724137931034
# nld	0.7302631578947368
# nld	0.5562913907284768
# swe	0.6173285198555957
# swe	0.579185520361991
# nld	0.6
# nld	0.5105263157894737
# nld	0.36507936507936506
# swe	0.8045977011494253
# swe	0.7588652482269503
# nld	0.6510067114093959
# swe	0.5272727272727272
# nld	0.6260162601626016
# nld	0.861878453038674
# swe	0.6964285714285714
# swe	0.6827586206896552
# swe	0.7214765100671141
# nld	0.7073170731707317
# nld	0.6864864864864865
# swe	0.6381578947368421
# nld	0.5
# swe	0.5140845070422535
# nld	0.8496732026143791
# nld	0.7816901408450704
# nld	0.7751479289940828
# nld	0.4966887417218543
# swe	0.7564102564102564
# swe	0.47398843930635837
# nld	0.528169014084507
# swe	0.5319148936170213
# swe	0.5806451612903226
# swe	0.8317307692307693
# nld	0.5603448275862069
# nld	0.603448275862069
# nld	0.6454545454545455
# swe	0.5952380952380952
# nld	0.8165680473372781
# nld	0.5789473684210527
# nld	0.6180555555555556
# swe	1.0
# swe	0.647887323943662
# swe	0.5319148936170213
# swe	0.4276729559748428
# nld	0.6796536796536796
# swe	0.9924242424242424
# swe	0.5957446808510638
# nld	0.8186813186813187
# swe	0.6125
# nld	0.8351648351648352
# nld	0.7394366197183099
# swe	0.5704225352112676
# nld	0.7368421052631579
# nld	0.8855421686746988
# swe	0.7958115183246073
# nld	0.5779816513761468
# swe	0.8864628820960698
# swe	0.9291338582677166
# nld	0.9126637554585153
# swe	0.4935897435897436
# swe	0.8235294117647058
# swe	0.8423645320197044
# nld	0.5431034482758621
# nld	0.49206349206349204
# swe	0.7933333333333333
# swe	0.48226950354609927
# swe	0.837696335078534
# nld	0.4858490566037736
# swe	0.3561643835616438
# swe	0.9117647058823529
# swe	0.615819209039548
# swe	0.4066666666666667
# swe	0.5568181818181818
# swe	0.5734265734265734
# nld	0.7327586206896551
# swe	0.5934065934065934
# swe	0.8118279569892473
# nld	0.5851851851851851
# swe	0.8497109826589595
# nld	0.48598130841121495
# swe	0.5378787878787878
# nld	0.7777777777777778
# swe	0.9732620320855615
# swe	0.6053811659192825
# nld	0.6690140845070423
# swe	0.5684210526315789
# swe	0.8011363636363636
# nld	0.7333333333333333
# swe	0.7797619047619048
# nld	0.7485029940119761
# nld	0.49295774647887325
# swe	0.7442748091603053
# nld	0.7919463087248322
# swe	0.38636363636363635
# nld	0.8223684210526315
# nld	0.7257142857142858
# nld	0.5434782608695652
# nld	0.5258620689655172
# swe	0.5303867403314917
# nld	0.47413793103448276
# swe	0.9625668449197861
# nld	0.5728155339805825
# nld	0.9111111111111111
# nld	0.7928994082840237
# swe	0.5874125874125874
# nld	0.5422535211267606
# nld	0.6240601503759399
# swe	0.5654761904761905
# nld	0.40397350993377484
# swe	0.44047619047619047
# nld	0.5086206896551724
# nld	0.7912087912087912
# swe	0.6117021276595744
# nld	0.6551724137931034
# nld	0.5086206896551724
# nld	0.5045871559633027
# swe	0.5527638190954773
# swe	0.9625668449197861
# swe	0.9233576642335767
# swe	0.697986577181208
# nld	0.4639175257731959
# nld	0.6551724137931034
# nld	0.592391304347826
# nld	0.5203252032520326
# nld	0.6331360946745562
# nld	0.5058823529411764
# swe	0.7889447236180904
# nld	0.5344827586206896
# swe	0.5822784810126582
# swe	0.8238636363636364
# swe	0.4230769230769231
# swe	0.6685082872928176
# nld	0.7758620689655172
# nld	0.5306122448979592
# swe	0.6488095238095238
# nld	0.5138888888888888
# swe	0.54
# nld	0.6369426751592356
# nld	0.5431034482758621
# nld	0.625
# swe	0.584070796460177
# swe	0.6095890410958904
# swe	0.7414965986394558
# swe	0.5029585798816568
# nld	0.7295597484276729
# nld	0.5422535211267606
# swe	0.9631578947368421
# nld	0.6408450704225352
# swe	0.9526315789473684
# nld	0.7633136094674556
# nld	0.47368421052631576
# swe	0.5873015873015873
# swe	0.569620253164557
# nld	0.5244755244755245
# nld	0.5974025974025974
# swe	0.8941176470588236
# nld	0.35714285714285715
# swe	0.8076923076923077
# nld	0.6408450704225352
# nld	0.5157232704402516
# swe	0.7784090909090909
# swe	0.647887323943662
# nld	0.5
# swe	0.9864253393665159
# swe	0.5636363636363636
# swe	0.990521327014218
# nld	0.7155172413793104
# swe	0.6510067114093959
# nld	0.7692307692307693
# nld	0.5657894736842105
# swe	0.5256410256410257
# swe	0.4479166666666667
# nld	0.5413533834586466
# nld	0.5431034482758621
# swe	0.7394366197183099
# swe	0.9807692307692307
# nld	0.5921052631578947
# nld	1.0
# nld	0.41379310344827586
# nld	0.8402061855670103
# nld	0.8156424581005587
# nld	0.4012345679012346
# nld	0.8305084745762712
# nld	0.6136363636363636
# nld	0.5379310344827586
# nld	0.6114649681528662
# nld	0.5492957746478874
# nld	0.8201058201058201
# nld	0.5431034482758621
# nld	0.4125874125874126
# nld	0.5772357723577236
# swe	0.4830188679245283
# swe	0.9010989010989011
# nld	0.7293233082706767
# nld	0.41284403669724773
# nld	0.7197452229299363
# swe	0.7873563218390804
# nld	0.8021978021978022
# nld	0.6649746192893401
# swe	0.48148148148148145
# nld	0.5789473684210527
# nld	0.593103448275862
# swe	0.7931034482758621
# nld	0.75
# nld	0.7247191011235955
# nld	0.8679245283018868
# nld	0.43448275862068964
# swe	0.6973684210526315
# nld	0.6724137931034483
# swe	0.8601694915254238
# swe	0.7536231884057971
# swe	0.4358974358974359
# swe	0.6266666666666667
# nld	0.603448275862069
# nld	0.4934210526315789
# nld	0.5775862068965517
# nld	0.4909090909090909
# nld	0.7413793103448276
# nld	0.6293706293706294
# swe	0.4246575342465753
# nld	0.6619718309859155
# swe	0.8866995073891626
# nld	0.4796747967479675
# swe	0.9014778325123153
# swe	0.8393782383419689
# swe	0.8011363636363636
# nld	0.8087431693989071
# swe	0.7724550898203593
# swe	0.9625668449197861
# swe	0.8160919540229885
# swe	0.7692307692307693
# swe	0.8103448275862069
# swe	0.8524590163934426
# swe	0.981042654028436
# swe	0.45977011494252873
# nld	0.5229357798165137
# nld	0.6026490066225165
# swe	0.7417582417582418
# swe	0.4873417721518987
# swe	0.5714285714285714
# nld	0.4959349593495935
# swe	0.6338028169014085
# nld	0.8143712574850299
# swe	0.9754901960784313
# nld	0.6551724137931034
# swe	0.8009708737864077
# swe	0.7966101694915254
# swe	0.7692307692307693
# swe	1.0
# swe	0.8911917098445595
# swe	0.7619047619047619
# nld	0.6896551724137931
# swe	0.6085271317829457
# nld	0.6308724832214765
# swe	1.0
# swe	0.5773809523809523
# swe	0.5053191489361702
# nld	0.7735849056603774
# swe	0.5714285714285714
# nld	0.5203252032520326
# swe	0.9657534246575342
# swe	0.7619047619047619
# swe	0.9117647058823529
# swe	1.0
# nld	0.48223350253807107
# swe	0.7705882352941177
# swe	0.9819004524886877
# nld	0.6120689655172413
# swe	0.475177304964539
# nld	0.6349206349206349
# nld	0.5
# swe	0.4166666666666667
# nld	0.43103448275862066
# swe	0.545
# swe	0.9848484848484849
# swe	0.7986577181208053
# swe	0.8275862068965517
# swe	0.5821917808219178
# swe	0.7747252747252747
# nld	0.834319526627219
# swe	0.8068181818181818
# swe	0.896774193548387
# swe	0.7659574468085106
# swe	0.7237569060773481
# swe	0.7633136094674556
# nld	0.49056603773584906
# swe	0.5654761904761905
# swe	1.0
# nld	0.5333333333333333
# swe	0.7142857142857143
# swe	0.6428571428571429
# nld	0.8496732026143791
# nld	0.5789473684210527
# nld	0.5939849624060151
# swe	0.8103448275862069
# swe	0.7058823529411765
# nld	0.7740112994350282
# swe	0.9736842105263158
# nld	0.7818181818181819
# swe	0.8846153846153846
# swe	0.7900552486187845
# swe	0.975975975975976
# swe	0.6627218934911243
# swe	0.9518716577540107
# nld	0.697986577181208
# swe	0.7727272727272727
# nld	0.5862068965517241
# swe	0.916256157635468
# swe	0.7536231884057971
# nld	0.49137931034482757
# swe	0.6830985915492958
# nld	0.7068965517241379
# swe	0.5269461077844312
# swe	0.6372549019607843
# nld	0.7692307692307693
# nld	0.7823529411764706
# swe	0.5637583892617449
# nld	0.5424528301886793
# nld	0.8888888888888888
# nld	0.45871559633027525
# swe	0.6331360946745562
# swe	0.49242424242424243
# swe	0.9848484848484849
# nld	0.753968253968254
# nld	0.5256410256410257
# nld	0.47586206896551725
# nld	0.4631578947368421
# nld	0.5263157894736842
# nld	1.0
# swe	0.44148936170212766
# nld	0.8095238095238095
# swe	0.671957671957672
# swe	0.9924242424242424
# swe	0.9211822660098522
# nld	0.6466165413533834
# nld	0.5740740740740741
# nld	0.6553398058252428
# nld	0.8135593220338984
# nld	0.5413533834586466
# swe	0.4772727272727273
# swe	0.46835443037974683
# nld	0.6820809248554913
# nld	0.7068965517241379
# nld	0.7692307692307693
# nld	0.39655172413793105
# swe	0.5422535211267606
# nld	0.5263157894736842
# nld	0.3458646616541353
# nld	0.6379310344827587
# swe	0.8472906403940886
# swe	0.9691629955947136
# nld	0.7909604519774012
# nld	0.52
# nld	0.5422535211267606
# swe	0.9732620320855615
# nld	0.5302013422818792
# nld	0.373015873015873
# nld	0.6379310344827587
# swe	0.7857142857142857
# nld	0.5862068965517241
# nld	0.47413793103448276
# nld	0.47413793103448276
# nld	0.6991869918699187
# swe	0.9039301310043668
# nld	0.75
# swe	0.7612903225806451
# swe	0.7557251908396947
# swe	0.9719626168224299
# nld	0.5927835051546392
# swe	0.7065217391304348
# swe	0.9732620320855615
# nld	0.7793103448275862
# nld	0.5684210526315789
# nld	0.4878048780487805
# nld	0.5086206896551724
# swe	0.5530973451327433
# swe	0.5893416927899686
# swe	0.9634703196347032
# swe	0.8928571428571429
# nld	0.5639097744360902
# nld	0.7588235294117647
# nld	0.5263157894736842
# nld	0.757396449704142
# nld	0.5298013245033113
# nld	0.6616541353383458
# swe	0.9797297297297297
# swe	0.9819004524886877
# swe	0.624113475177305
# nld	0.6190476190476191
# swe	0.8103448275862069
# nld	0.8806584362139918
# nld	0.5140845070422535
# swe	0.5490196078431373
# nld	0.8806584362139918
# swe	0.9672897196261683
# swe	0.5422535211267606
# swe	0.9679144385026738
# swe	0.8238636363636364
# swe	0.618421052631579
# swe	0.8817733990147784
# swe	0.6904761904761905
# nld	0.6120689655172413
# nld	0.5
# swe	0.9857142857142858
# swe	0.7978142076502732
# nld	0.706766917293233
# nld	0.5775862068965517
# nld	0.6293103448275862
# nld	0.4396551724137931
# nld	0.7633136094674556
# nld	0.7142857142857143
# swe	0.5140845070422535
# swe	0.45774647887323944
# swe	0.7931034482758621
# swe	0.7197452229299363
# swe	0.9058823529411765
# nld	0.4224137931034483
# nld	0.8165680473372781
# nld	0.4224137931034483
# nld	0.6637931034482759
# nld	0.6016260162601627
# nld	0.7764705882352941
# nld	0.6992481203007519
# swe	0.618421052631579
# swe	0.4772727272727273
# swe	0.9615384615384616
# swe	0.8160919540229885
# nld	0.8552631578947368
# nld	0.6504065040650406
# swe	0.5933333333333334
# swe	0.36764705882352944
# nld	0.8351648351648352
# nld	0.6666666666666666
# nld	0.6825396825396826
# swe	0.6815286624203821
# nld	0.7413793103448276
# swe	0.38461538461538464
# nld	0.5862068965517241
# swe	0.9624413145539906
# nld	0.8176470588235294
# swe	0.3802083333333333
# swe	0.5311004784688995
# nld	0.6016260162601627
# nld	0.4968553459119497
# swe	0.4642857142857143
# nld	0.49746192893401014
# nld	0.49375
# swe	0.6515151515151515
# swe	0.6926605504587156
# swe	0.6544502617801047
# nld	0.5
# swe	0.9541284403669725
# swe	0.6
# swe	0.8275862068965517
# swe	1.0
# nld	0.7241379310344828
# nld	0.6879432624113475
# swe	0.6352459016393442
# nld	0.5344827586206896
# swe	0.44366197183098594
# swe	0.9294117647058824
# swe	0.9541284403669725
# swe	0.5833333333333334
# swe	0.528169014084507
# swe	0.6515837104072398
# swe	0.9845360824742269
# nld	0.5961538461538461
# swe	0.8106796116504854
# swe	0.6012658227848101
# nld	0.8165680473372781
# nld	0.7013888888888888
# swe	0.5973154362416108
# nld	0.5431034482758621
# nld	0.7241379310344828
# swe	0.7988505747126436
# swe	0.90625
# swe	0.46296296296296297
# nld	0.7526315789473684
# nld	0.7928994082840237
# nld	0.49624060150375937
# swe	0.9015748031496063
# swe	0.9526315789473684
# nld	0.3851851851851852
# nld	0.5517241379310345
# swe	0.8588235294117647
# nld	0.5862068965517241
# swe	0.8512820512820513
# nld	0.5338345864661654
# swe	0.9821428571428571
# swe	0.7928994082840237
# swe	0.5175879396984925
# nld	0.4835164835164835
# nld	0.47586206896551725
# swe	0.7302631578947368
# swe	0.9732620320855615
# nld	0.6305732484076433
# swe	0.8615384615384616
# nld	0.807909604519774
# nld	0.5140845070422535
# nld	0.7450980392156863
# swe	0.6549295774647887
# nld	0.49137931034482757
# swe	0.4642857142857143
# nld	0.5344827586206896
# nld	0.6551724137931034
# nld	0.5045871559633027
# swe	0.44936708860759494
# swe	0.7588652482269503
# nld	0.6432432432432432
# nld	0.4793388429752066
# nld	0.6178343949044586
# nld	0.5297619047619048
# swe	0.8589743589743589
# nld	0.8033707865168539
# nld	0.6206896551724138
# swe	0.4265402843601896
# nld	0.8402366863905325
# swe	0.7802197802197802
# nld	0.630057803468208
# swe	0.7559523809523809
# nld	0.7916666666666666
# nld	0.5948275862068966
# swe	0.47183098591549294
# swe	0.5932203389830508
# swe	0.7470588235294118
# swe	0.654320987654321
# swe	0.8941176470588236
# nld	0.6346153846153846
# swe	0.5326633165829145
# nld	0.6120689655172413
# swe	0.4393939393939394
# nld	0.47183098591549294
# swe	1.0
# swe	0.637065637065637
# nld	0.7007042253521126
# swe	0.6779661016949152
# swe	0.8764705882352941
# swe	0.46994535519125685
# nld	0.4528301886792453
# swe	0.4491017964071856
# nld	0.6111111111111112
# nld	0.6370370370370371
# swe	0.7853107344632768
# swe	0.9803921568627451
# nld	0.7751479289940828
# nld	0.6910569105691057
# nld	0.5613207547169812
# nld	0.7944444444444444
# nld	0.6165413533834586
# swe	0.5291005291005291
# nld	0.718562874251497
# swe	0.9458128078817734
# swe	0.8791208791208791
# nld	0.8206521739130435
# nld	0.7763157894736842
# nld	0.6444444444444445
# nld	0.8042328042328042
# swe	0.4807692307692308
# nld	0.6842105263157895
# swe	0.5297619047619048
# nld	0.5431034482758621
# swe	0.43564356435643564
# nld	0.6551724137931034
# nld	0.5588235294117647
# nld	0.6358381502890174
# nld	0.6379310344827587
# swe	0.8516483516483516
# swe	0.5
# nld	0.7006802721088435
# nld	0.49206349206349204
# swe	0.946524064171123
# nld	0.7213930348258707
# nld	0.6120689655172413
# swe	0.9118942731277533
# nld	0.5081967213114754
# nld	0.43103448275862066
# swe	0.9513274336283186
# nld	0.7771084337349398
# nld	0.5786163522012578
# nld	0.6150234741784038
# nld	0.6269230769230769
# swe	0.4604651162790698
# nld	0.603448275862069
# swe	0.9893048128342246
# nld	0.7150259067357513
# nld	0.8059701492537313
# swe	0.65
# nld	0.49137931034482757
# swe	0.9732620320855615
# nld	0.4482758620689655
# nld	0.7823529411764706
# swe	0.6892655367231638
# swe	0.49645390070921985
# swe	0.541095890410959
# nld	0.7293233082706767
# nld	0.7291666666666666
# swe	0.8387096774193549
# nld	0.8235294117647058
# swe	0.5055555555555555
# nld	0.6968085106382979
# nld	0.4959349593495935
# nld	0.6
# nld	0.7046979865771812
# nld	0.905829596412556
# nld	0.5263157894736842
# nld	0.75
# nld	0.5948275862068966
# swe	0.7909604519774012
# nld	0.45689655172413796
# swe	0.44366197183098594
# swe	0.7487437185929648
# nld	0.46551724137931033
# nld	0.5823529411764706
# nld	0.5258620689655172
# nld	0.6497175141242938
# nld	0.5633802816901409
# nld	0.4375
# swe	0.5991379310344828
# nld	0.7611111111111111
# swe	0.6736842105263158
# nld	0.49624060150375937
# swe	0.985
# nld	0.9209486166007905
# swe	0.5563380281690141
# nld	0.49137931034482757
# swe	0.6666666666666666
# swe	0.6845238095238095
# nld	0.6637931034482759
# swe	0.8723404255319149
# swe	0.955
# nld	0.7374301675977654
# swe	0.7978723404255319
# nld	0.8074866310160428
# swe	0.6484848484848484
# swe	0.0
# swe	0.6428571428571429
# nld	0.3873239436619718
# nld	0.5384615384615384
# nld	0.8121546961325967
# nld	0.6530612244897959
# nld	0.45774647887323944
# nld	0.562874251497006
# swe	0.4788732394366197
# swe	0.7612903225806451
# swe	0.4726027397260274
# swe	0.8456375838926175
# nld	0.5853658536585366
# nld	0.6148648648648649
# swe	0.9226804123711341
# swe	0.9261083743842364
# swe	0.5675675675675675
# swe	0.5422535211267606
# swe	0.7872340425531915
# nld	0.8210526315789474
# nld	0.8117647058823529
# nld	0.5688073394495413
# nld	0.6276595744680851
# nld	0.6992481203007519
# nld	0.543859649122807
# swe	1.0
# nld	0.5825242718446602
# nld	0.6842105263157895
# swe	0.8074866310160428
# nld	0.9470198675496688
# nld	0.6710526315789473
# nld	0.5079365079365079
# swe	0.5082872928176796
# swe	0.851063829787234
# swe	0.7961165048543689
# swe	0.4973544973544973
# swe	0.9254658385093167
# swe	0.6549295774647887
# nld	0.5948275862068966
# swe	0.8823529411764706
# nld	0.6447368421052632
# swe	0.6549295774647887
# swe	0.5152838427947598
# nld	0.6383763837638377
# swe	0.4318181818181818
# nld	0.7171052631578947
# swe	0.8717948717948718
# nld	0.5845070422535211
# nld	0.8108108108108109
# nld	0.7154471544715447
# nld	0.6424581005586593
# swe	0.8509316770186336
# nld	0.6428571428571429
# swe	0.8409090909090909
# swe	0.4427083333333333
# swe	0.8225806451612904
# swe	0.9228395061728395
# swe	0.8888888888888888
# swe	0.4406779661016949
# swe	1.0
# swe	0.9757281553398058
# swe	1.0
# swe	1.0
# nld	0.7241379310344828
# nld	0.7155172413793104
# swe	0.9518716577540107
# swe	1.0
# swe	0.7307692307692307
# swe	0.8866995073891626
# swe	0.9015151515151515
# nld	0.42857142857142855
# nld	0.7810650887573964
# nld	0.49295774647887325
# nld	0.6442953020134228
# swe	0.5515151515151515
# nld	0.6458333333333334
# swe	0.7292817679558011
# swe	0.7840909090909091
# swe	0.8125
# swe	0.6624203821656051
# nld	0.7923497267759563
# swe	0.5804195804195804
# swe	0.9848484848484849
# nld	0.8
# swe	0.5675675675675675
# nld	0.5603448275862069
# nld	0.5939849624060151
# nld	0.6711409395973155
# swe	0.6394230769230769
# nld	0.5238095238095238
# swe	0.5915492957746479
# nld	0.7564766839378239
# swe	0.9815668202764977
# nld	0.8026315789473685
# swe	0.8717948717948718
# nld	0.47413793103448276
# nld	0.6619718309859155
# nld	0.788235294117647
# swe	0.71875
# swe	0.9852216748768473
# nld	0.5781990521327014
# nld	0.618421052631579
# nld	0.6206896551724138
# nld	0.7919463087248322
# nld	0.5789473684210527
# swe	0.8031914893617021
# nld	0.7722222222222223
# nld	0.7810650887573964
# nld	0.603448275862069
# swe	0.8763440860215054
# nld	0.9436619718309859
# swe	0.6108597285067874
# swe	0.7411764705882353
# nld	0.5948275862068966
# swe	0.5352112676056338
# nld	0.6912751677852349
# nld	0.6711409395973155
# nld	0.5980392156862745
# swe	0.7751479289940828
# nld	0.6015037593984962
# nld	0.8888888888888888
# swe	0.9901960784313726
# swe	0.8409090909090909
# swe	0.553030303030303
# nld	0.7700534759358288
# nld	0.5586206896551724
# swe	1.0
# nld	0.7413793103448276
# swe	0.5238095238095238
# swe	0.6114649681528662
# nld	0.46616541353383456
# nld	0.5775862068965517
# nld	0.5704225352112676
# nld	0.5492957746478874
# swe	1.0
# nld	0.7134146341463414
# swe	0.6510067114093959
# swe	0.8169014084507042
# swe	0.5123456790123457
# swe	0.7788944723618091
# nld	0.6190476190476191
# nld	0.6818181818181818
# nld	0.7627118644067796
# swe	1.0
# swe	0.7763157894736842
# swe	0.5804195804195804
# nld	0.4819277108433735
# nld	0.5772357723577236
# nld	0.5873015873015873
# nld	0.4619883040935672
# nld	0.8813559322033898
# nld	0.5620915032679739
# nld	0.5408805031446541
# swe	0.5704225352112676
# nld	0.5948275862068966
# nld	0.6197183098591549
# swe	0.6163522012578616
# swe	0.7197452229299363
# nld	0.7302631578947368
# nld	0.5086206896551724
# swe	0.8275862068965517
# nld	0.5759493670886076
# nld	0.4968553459119497
# swe	0.4935897435897436
# nld	0.47368421052631576
# nld	0.46710526315789475
# nld	0.4897959183673469
# nld	0.4391891891891892
# nld	0.5555555555555556
# swe	0.5288135593220339
# swe	0.47183098591549294
# nld	0.8265895953757225
# swe	0.592057761732852
# nld	0.6120689655172413
# swe	0.7692307692307693
# swe	1.0
# swe	0.9625668449197861
# nld	0.7810650887573964
# swe	0.9408866995073891
# nld	0.6459143968871596
# swe	0.7677165354330708
# nld	0.47904191616766467
# swe	0.6547619047619048
# nld	0.6111111111111112
# swe	0.990521327014218
# swe	0.8068181818181818
# swe	0.9411764705882353
# nld	0.47413793103448276
# nld	0.6052631578947368
# nld	0.8734939759036144
# nld	0.4396551724137931
# swe	0.7988165680473372
# nld	0.48623853211009177
# swe	0.8275862068965517
# nld	0.7218045112781954
# swe	0.8655913978494624
# swe	0.9864253393665159
# swe	0.9625668449197861
# nld	0.5
# swe	0.4444444444444444
# swe	0.9290322580645162
# swe	1.0
# nld	0.7208121827411168
# swe	0.423728813559322
# swe	1.0
# nld	0.7005649717514124
# swe	0.7808988764044944
# swe	0.9924242424242424
# nld	0.4014084507042254
# nld	0.6120689655172413
# swe	0.9507389162561576
# nld	0.5408805031446541
# swe	0.4154929577464789
# swe	0.8901098901098901
# swe	0.8640776699029126
# nld	0.5673076923076923
# swe	0.7802197802197802
# nld	0.5862068965517241
# swe	0.5865384615384616
# nld	0.8157894736842105
# nld	0.5563380281690141
# swe	0.7923497267759563
# nld	0.6293103448275862
# swe	0.717391304347826
# nld	0.6973684210526315
# nld	0.47413793103448276
# nld	0.6810344827586207
# swe	0.6408450704225352
# swe	0.81
# swe	0.44594594594594594
# nld	0.6379310344827587
# swe	0.5915492957746479
# nld	0.4482758620689655
# nld	0.6369426751592356
# swe	0.8681318681318682
# swe	0.4807692307692308
# nld	0.5704697986577181
# swe	0.5422535211267606
# swe	0.5684931506849316
# nld	0.3888888888888889
# swe	0.8074866310160428
# swe	0.593939393939394
# swe	0.6142131979695431
# swe	0.6232876712328768
# nld	0.6551724137931034
# swe	0.56353591160221
# nld	0.4972972972972973
# swe	0.7857142857142857
# nld	0.6255924170616114
# nld	0.6724137931034483
# swe	0.7016574585635359
# nld	0.5416666666666666
# swe	0.7816901408450704
# swe	1.0
# swe	0.9900497512437811
# nld	0.5517241379310345
# nld	0.776536312849162
# nld	0.6666666666666666
# nld	0.5
# swe	0.7712418300653595
# nld	0.42105263157894735
# nld	0.5231788079470199
# nld	0.6529411764705882
# nld	0.5471698113207547
# swe	0.7077922077922078
# swe	0.47023809523809523
# swe	0.6301369863013698
# swe	0.7840909090909091
# swe	0.5119047619047619
# swe	0.5774647887323944
# swe	0.7738095238095238
# nld	0.556390977443609
# nld	0.5
# nld	0.5939849624060151
# swe	0.918552036199095
# swe	0.9516908212560387
# nld	0.7758620689655172
# swe	0.6643356643356644
# swe	0.896551724137931
# nld	0.5310344827586206
# swe	0.8218390804597702
# nld	0.6691729323308271
# nld	0.7966101694915254
# nld	0.8229166666666666
# swe	0.6772151898734177
# swe	0.7853107344632768
# nld	0.5481481481481482
# swe	0.9625668449197861
# swe	0.503030303030303
# nld	0.5609756097560976
# nld	0.5714285714285714
# nld	0.8315789473684211
# swe	0.6595744680851063
# swe	0.8061224489795918
# swe	0.7978142076502732
# nld	0.6702702702702703
# swe	0.9225806451612903
# swe	0.8009049773755657
# nld	0.6338028169014085
# swe	0.6883116883116883
# swe	0.9529411764705882
# swe	0.3974358974358974
# swe	0.9082278481012658
# swe	0.49700598802395207
# swe	0.7797619047619048
# nld	0.7394366197183099
# swe	0.5985915492957746
# nld	0.5862068965517241
# swe	0.785234899328859
# swe	1.0
# swe	0.6181818181818182
# swe	0.7613636363636364
# swe	0.7696629213483146
# nld	0.5192307692307693
# swe	0.7388535031847133
# swe	0.9907407407407407
# nld	0.6896551724137931
# swe	0.5563380281690141
# swe	0.5205479452054794
# swe	0.4064516129032258
# swe	0.5704697986577181
# nld	0.7664670658682635
# nld	0.58125
# nld	0.5486111111111112
# nld	0.4652777777777778

# %%
results = []
for i in range(len(test_data)):
    results.append({'Language':data.loc[data['match_rate_lang_'+str(i)].idxmax()]['lang'], 'Score':data.loc[data['match_rate_lang_'+str(i)].idxmax()]['match_rate_lang_'+str(i)]})
res_df = pd.DataFrame(results)
res_df.head()
# Out:
#   Language     Score
# 0      nld  0.591549
# 1      swe  0.976744
# 2      swe  0.565789
# 3      swe  0.566434
# 4      nld  0.785311

# %%
res_df['Score'].groupby(res_df['Language']).mean()
# Out:
# Language
# nld    0.628586
# swe    0.727538
# Name: Score, dtype: float64
