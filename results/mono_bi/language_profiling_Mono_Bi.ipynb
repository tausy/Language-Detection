# %% [markdown]
# # Creation of Language Training Profiles

# %% [markdown]
# ## 1. Required Imports

# %%
import nltk
from nltk.tokenize import word_tokenize
import pandas as pd

# %% [markdown]
# ## 2. Read Wili-2018 Dataset and filter it for 34 European Languages

# %%
data = pd.read_csv('/Users/ashwinkumar/Desktop/MLProj/wili-2018/x_train.txt', sep='\r\n', header=None, engine='python')
res = pd.read_csv('/Users/ashwinkumar/Desktop/MLProj/wili-2018/y_train.txt', sep='\r\n', header=None, engine='python')
langs = ['slk']
#'nld','swe']
#,'tur','lat','dan','por','fra','bos','bul','gle','be-tarask','spa','isl','cym','srp','ita','fin','cat','ron','ces','rus','lit','sqi','slk','ukr','hrv','eng','mlt','hye','nno','hun','deu','mwl','pol','ell','ltz']
data['1'] = res
data.columns = ['text', 'lang']
data = data[data['lang'].isin(langs)].reset_index(drop=True)
data.head()
# Out:
#                                                 text lang
# 0  január 2000 – po voľbách sa časť poslancov zvo...  slk
# 1  Kniha obsahuje kompiláciu výrokov a rozhovorov...  slk
# 2  Waters bývalých spoluhráčov zažaloval za neopr...  slk
# 3  Třebovice je obec v Česku v okrese Ústí nad Or...  slk
# 4  Vydávala periodiká Časopis Muzeálnej slovenske...  slk

# %% [markdown]
# ## 3. Print filtered Lang Samples and Shape of Dataframe

# %%
print(data.head())
data.shape
# Out:
#                                                 text lang
# 0  január 2000 – po voľbách sa časť poslancov zvo...  slk
# 1  Kniha obsahuje kompiláciu výrokov a rozhovorov...  slk
# 2  Waters bývalých spoluhráčov zažaloval za neopr...  slk
# 3  Třebovice je obec v Česku v okrese Ústí nad Or...  slk
# 4  Vydávala periodiká Časopis Muzeálnej slovenske...  slk
# (500, 2)

# %% [markdown]
# ## 4. Preprocess Lang Data(Remove punctuations and digits)

# %%
data['text'] = data['text'].str.replace(r'[^\w\s]+', '')
data['text'] = data['text'].str.replace(r'[\d]+', '')
data['text'] = data['text'].astype(str).str.lower()
data.shape
# Out:
# (500, 2)

# %% [markdown]
# ## 4. Tokenize Lang Data to Prepare Lang Profiles

# %%
#data = data.groupby('lang')['text'].apply(' '.join).reset_index()
data['text'] = data.text.apply(word_tokenize)
data.shape
# Out:
# (500, 2)

# %% [markdown]
# ## 5. Function to Create N-GRAMS

# %%
def word2ngrams(text, n=2):
  """ Convert word into character ngrams. """
  return [text[i:i+n] for i in range(len(text)-n+1)]

# %% [markdown]
# ## 6. Generate Lang Profiles using Mono, Bi and Tri GRAMS

# %%
ngrams = []
data['ngrams'] = ''
for lang in data.text:
    lang_ngram = []
    for word in lang:
        lang_ngram = lang_ngram + word2ngrams(word,1) + word2ngrams(word,2) 
    lang_ngram = sorted(list(set(lang_ngram)), key=len)
    ngrams.append(lang_ngram)

for i in range(len(ngrams)):
    data.at[i, 'ngrams'] = ngrams[i]
data.shape
# Out:
# (500, 3)

# %%
data.head()
# Out:
#                                                 text lang  \
# 0  [január, po, voľbách, sa, časť, poslancov, zvo...  slk
# 1  [kniha, obsahuje, kompiláciu, výrokov, a, rozh...  slk
# 2  [waters, bývalých, spoluhráčov, zažaloval, za,...  slk
# 3  [třebovice, je, obec, v, česku, v, okrese, úst...  slk
# 4  [vydávala, periodiká, časopis, muzeálnej, slov...  slk
#
#                                               ngrams
# 0  [í, a, e, r, š, ľ, t, ž, á, o, ô, ť, z, c, b, ...
# 1  [í, a, g, e, ó, r, š, t, ž, á, o, ô, ť, z, c, ...
# 2  [í, a, e, g, ó, ď, r, š, t, w, ž, á, o, ť, z, ...
# 3  [í, a, e, r, ľ, t, ž, á, o, z, c, b, n, p, č, ...
# 4  [í, a, e, r, t, á, o, z, b, n, p, č, l, é, ý, ...

# %% [markdown]
# ## 7. Write Generated Lang Profiles in JSON

# %%
data.to_json('/Users/ashwinkumar/Desktop/MLProj/wili-2018/lang_profiles.json', orient='values')

# %% [markdown]
# # Detect Language using Test Language Profiles

# %% [markdown]
# ## 1. Load Test Data

# %%
test_data = pd.read_csv('/Users/ashwinkumar/Desktop/MLProj/wili-2018/x_test.txt', sep='\r\n', header=None, engine='python')
test_res = pd.read_csv('/Users/ashwinkumar/Desktop/MLProj/wili-2018/y_test.txt', sep='\r\n', header=None, engine='python')
test_langs = ['slk']
    #'swe','nld','tur','lat','dan','por','fra','bos','bul','gle','be-tarask','spa','isl','cym','srp','ita','fin','cat','ron','ces','rus','lit','sqi','slk','ukr','hrv','eng','mlt','hye','nno','hun','deu','mwl','pol','ell','ltz']
test_data['1'] = test_res
test_data.columns = ['text', 'lang']
test_data = test_data[test_data['lang'].isin(langs)].reset_index(drop=True)
test_data.head()
# Out:
#                                                 text lang
# 0  Podujal sa preto rozlúštiť tento paradox. Syst...  slk
# 1  V roku 2002 ho prezident George W. Bush vymeno...  slk
# 2  V hudbe sa za Underground označuje smer, ktorý...  slk
# 3  Do roku 1919 mladé talenty zo Slovenska navšte...  slk
# 4  George Hammond nastúpil ako generál v prvom di...  slk

# %% [markdown]
# ## 2. Print filtered Lang Test Samples and Shape of Dataframe

# %%
print(test_data.head())
test_data.shape
# Out:
#                                                 text lang
# 0  Podujal sa preto rozlúštiť tento paradox. Syst...  slk
# 1  V roku 2002 ho prezident George W. Bush vymeno...  slk
# 2  V hudbe sa za Underground označuje smer, ktorý...  slk
# 3  Do roku 1919 mladé talenty zo Slovenska navšte...  slk
# 4  George Hammond nastúpil ako generál v prvom di...  slk
# (500, 2)

# %% [markdown]
# ## 3. Preprocess Test Lang Data(Remove punctuations and digits)

# %%
test_data['text'] = test_data['text'].str.replace(r'[^\w\s]+', '')
test_data['text'] = test_data['text'].str.replace(r'[\d]+', '')
test_data['text'] = test_data['text'].astype(str).str.lower()
test_data.head()
# Out:
#                                                 text lang
# 0  podujal sa preto rozlúštiť tento paradox syste...  slk
# 1  v roku  ho prezident george w bush vymenoval d...  slk
# 2  v hudbe sa za underground označuje smer ktorý ...  slk
# 3  do roku  mladé talenty zo slovenska navštevova...  slk
# 4  george hammond nastúpil ako generál v prvom di...  slk

# %% [markdown]
# ## 4. Tokenize Test Lang Data to Prepare Lang Profiles

# %%
test_data['text'] = test_data.text.apply(word_tokenize)
test_data.head()
# Out:
#                                                 text lang
# 0  [podujal, sa, preto, rozlúštiť, tento, paradox...  slk
# 1  [v, roku, ho, prezident, george, w, bush, vyme...  slk
# 2  [v, hudbe, sa, za, underground, označuje, smer...  slk
# 3  [do, roku, mladé, talenty, zo, slovenska, navš...  slk
# 4  [george, hammond, nastúpil, ako, generál, v, p...  slk

# %% [markdown]
# ## 5. Generate Test Lang Profiles using Mono, Bi and Tri GRAMS

# %%
ngrams = []
test_data['ngrams'] = ''
for lang in test_data.text:
    lang_ngram = []
    for word in lang:
        lang_ngram = lang_ngram + word2ngrams(word,1) + word2ngrams(word,2) 
    lang_ngram = sorted(list(set(lang_ngram)), key=len)
    ngrams.append(lang_ngram)
#print(ngrams)
for i in range(len(ngrams)):
    test_data.at[i, 'ngrams'] = ngrams[i]
test_data.head()
# Out:
#                                                 text lang  \
# 0  [podujal, sa, preto, rozlúštiť, tento, paradox...  slk
# 1  [v, roku, ho, prezident, george, w, bush, vyme...  slk
# 2  [v, hudbe, sa, za, underground, označuje, smer...  slk
# 3  [do, roku, mladé, talenty, zo, slovenska, navš...  slk
# 4  [george, hammond, nastúpil, ako, generál, v, p...  slk
#
#                                               ngrams
# 0  [í, a, e, r, š, ľ, t, ž, á, o, ť, z, c, b, n, ...
# 1  [a, g, e, r, š, t, w, á, o, ť, z, c, b, n, p, ...
# 2  [í, a, g, e, ó, r, š, ľ, t, ž, á, o, z, c, b, ...
# 3  [í, a, e, ó, r, š, t, ž, á, o, ť, z, c, b, n, ...
# 4  [í, a, g, e, ď, r, t, w, ž, á, o, ô, ť, z, c, ...

# %%
test_data.shape
# Out:
# (500, 3)

# %%
print(data['ngrams'][0])
print(test_data['ngrams'][0])
# Out:
# ['í', 'a', 'e', 'r', 'š', 'ľ', 't', 'ž', 'á', 'o', 'ô', 'ť', 'z', 'c', 'b', 'n', 'p', 'č', 'l', 'ý', 'i', 'm', 'k', 'd', 's', 'u', 'ú', 'j', 'h', 'v', 'ča', 'ol', 'tr', 'em', 'ún', 'va', 'án', 'kú', 'ul', 'ľb', 'od', 'uá', 'mi', 'li', 'mo', 'áš', 'ši', 'nu', 'no', 'ik', 'ož', 'en', 'zu', 'ti', 'co', 'sd', 'aj', 'dz', 'ck', 'an', 'ko', 'ch', 'vo', 'ní', 'po', 'at', 'sť', 'in', 'de', 'os', 'do', 'oľ', 'sv', 'ím', 'rá', 'zv', 'ťa', 'ic', 'ni', 'sk', 'vú', 'sl', 'ja', 've', 'mk', 'ôv', 'ji', 'im', 'ri', 'dn', 'dk', 'st', 'nc', 'ša', 'za', 're', 'la', 'ži', 'ed', 'il', 'oj', 'ra', 'ok', 'me', 'du', 'ác', 'át', 'nd', 'lo', 'zi', 'ný', 'kr', 'ýc', 'it', 'sa', 'ku', 'bá', 'lá', 'le', 'ár', 'ur', 'iu', 'ns', 'as', 'iv', 'es', 'pô', 'vr', 'al', 'ov']
# ['í', 'a', 'e', 'r', 'š', 'ľ', 't', 'ž', 'á', 'o', 'ť', 'z', 'c', 'b', 'n', 'p', 'x', 'č', 'l', 'ý', 'i', 'm', 'y', 'k', 'd', 's', 'u', 'ú', 'j', 'h', 'v', 'by', 'dš', 'em', 'ol', 'kt', 'ar', 'ej', 'sú', 'vý', 'ky', 'ne', 'od', 'mi', 'li', 'uj', 'uk', 'yť', 'zl', 'ás', 'mú', 'nt', 'no', 'ík', 'ik', 'íc', 'dr', 'en', 'zu', 'še', 'ti', 'pý', 'pí', 'ám', 'ek', 'dp', 'ck', 'oz', 'mu', 'ox', 'ko', 'ap', 'ch', 'vo', 'iť', 'um', 'bo', 'ní', 'áz', 'lú', 'po', 'at', 'di', 'eb', 'in', 'de', 'do', 'oľ', 'dc', 'ká', 'kl', 'úš', 'že', 'ís', 'ľa', 'ic', 'ni', 'ie', 'ma', 'pr', 'pa', 'sl', 'ou', 'er', 'ot', 'oc', 'ja', 'ud', 'vi', 'so', 've', 'mk', 'ln', 'ia', 'be', 'ri', 'ci', 'bu', 'ho', 'dn', 'st', 'šľ', 'av', 'úd', 'za', 're', 'jú', 'sá', 'št', 'rý', 'ký', 'ed', 'il', 'ež', 'ľv', 'ra', 'ok', 'tá', 'om', 'me', 'ad', 'du', 'ýt', 'my', 'te', 'sy', 'or', 'id', 'čo', 'zk', 'zi', 'ný', 'kr', 'na', 'to', 'mý', 'it', 'sa', 'ýš', 'da', 'el', 'bá', 'lá', 'al', 'le', 'ro', 'ak', 'dá', 'sn', 'ád', 'as', 'es', 'dv', 'ta', 'si', 'ým', 'ľu', 'et', 'ys', 'se', 'is', 'ov']

# %%
data.shape
# Out:
# (500, 3)

# %%
UB = 0.95
LB = 0.92

for i in range(len(test_data)):
    for j in range(len(data)):
        data.at[j, 'match_rate_lang_'+str(i)] = len(set(test_data.iloc[i]['ngrams']).intersection(data.iloc[j]['ngrams']))/len(data.iloc[j]['ngrams'])
data.head()
# Out:
#                                                 text lang  \
# 0  [január, po, voľbách, sa, časť, poslancov, zvo...  slk
# 1  [kniha, obsahuje, kompiláciu, výrokov, a, rozh...  slk
# 2  [waters, bývalých, spoluhráčov, zažaloval, za,...  slk
# 3  [třebovice, je, obec, v, česku, v, okrese, úst...  slk
# 4  [vydávala, periodiká, časopis, muzeálnej, slov...  slk
#
#                                               ngrams  match_rate_lang_0  \
# 0  [í, a, e, r, š, ľ, t, ž, á, o, ô, ť, z, c, b, ...           0.607692
# 1  [í, a, g, e, ó, r, š, t, ž, á, o, ô, ť, z, c, ...           0.475113
# 2  [í, a, e, g, ó, ď, r, š, t, w, ž, á, o, ť, z, ...           0.500000
# 3  [í, a, e, r, ľ, t, ž, á, o, z, c, b, n, p, č, ...           0.660714
# 4  [í, a, e, r, t, á, o, z, b, n, p, č, l, é, ý, ...           0.653846
#
#    match_rate_lang_1  match_rate_lang_2  match_rate_lang_3  match_rate_lang_4  \
# 0           0.515385           0.492308           0.623077           0.746154
# 1           0.361991           0.416290           0.511312           0.615385
# 2           0.390110           0.423077           0.521978           0.681319
# 3           0.500000           0.580357           0.642857           0.741071
# 4           0.490385           0.548077           0.682692           0.750000
#
#    match_rate_lang_5  match_rate_lang_6         ...           \
# 0           0.484615           0.538462         ...
# 1           0.343891           0.393665         ...
# 2           0.384615           0.423077         ...
# 3           0.544643           0.589286         ...
# 4           0.557692           0.461538         ...
#
#    match_rate_lang_490  match_rate_lang_491  match_rate_lang_492  \
# 0             0.415385             0.569231             0.676923
# 1             0.361991             0.488688             0.615385
# 2             0.384615             0.532967             0.692308
# 3             0.419643             0.571429             0.714286
# 4             0.451923             0.692308             0.798077
#
#    match_rate_lang_493  match_rate_lang_494  match_rate_lang_495  \
# 0             0.400000             0.361538             0.684615
# 1             0.312217             0.289593             0.610860
# 2             0.362637             0.351648             0.675824
# 3             0.446429             0.410714             0.705357
# 4             0.500000             0.413462             0.730769
#
#    match_rate_lang_496  match_rate_lang_497  match_rate_lang_498  \
# 0             0.476923             0.400000             0.715385
# 1             0.429864             0.289593             0.592760
# 2             0.412088             0.313187             0.670330
# 3             0.517857             0.535714             0.750000
# 4             0.538462             0.432692             0.740385
#
#    match_rate_lang_499
# 0             0.407692
# 1             0.321267
# 2             0.373626
# 3             0.446429
# 4             0.442308
#
# [5 rows x 503 columns]

# %%
print('Language\tScore')
for i in range(len(test_data)):
    print(data.loc[data['match_rate_lang_'+str(i)].idxmax()]['lang']+'\t'+str(data.loc[data['match_rate_lang_'+str(i)].idxmax()]['match_rate_lang_'+str(i)]))
# Out:
# Language	Score
# slk	0.7289719626168224
# slk	0.6428571428571429
# slk	0.651685393258427
# slk	0.7653061224489796
# slk	0.8909090909090909
# slk	0.6261682242990654
# slk	0.6206896551724138
# slk	0.723404255319149
# slk	0.7264150943396226
# slk	0.7916666666666666
# slk	0.8426966292134831
# slk	0.5833333333333334
# slk	0.7037037037037037
# slk	0.625
# slk	0.7641509433962265
# slk	0.651685393258427
# slk	0.6701030927835051
# slk	0.6292134831460674
# slk	0.7191011235955056
# slk	0.7254901960784313
# slk	0.8085106382978723
# slk	0.7962962962962963
# slk	0.594059405940594
# slk	0.7528089887640449
# slk	0.6608695652173913
# slk	0.9401709401709402
# slk	0.6063829787234043
# slk	0.7078651685393258
# slk	0.6039603960396039
# slk	0.6454545454545455
# slk	0.7528089887640449
# slk	0.5619047619047619
# slk	0.7446808510638298
# slk	0.6636363636363637
# slk	0.6527777777777778
# slk	0.6506024096385542
# slk	0.7289719626168224
# slk	0.7435897435897436
# slk	0.5263157894736842
# slk	0.5046728971962616
# slk	0.635593220338983
# slk	0.6506849315068494
# slk	0.5154639175257731
# slk	0.6582278481012658
# slk	0.6538461538461539
# slk	0.5714285714285714
# slk	0.5263157894736842
# slk	0.6792452830188679
# slk	0.6567164179104478
# slk	0.900990099009901
# slk	0.6329113924050633
# slk	0.7425742574257426
# slk	0.7446808510638298
# slk	0.8316831683168316
# slk	0.8152173913043478
# slk	0.7307692307692307
# slk	0.6119402985074627
# slk	0.6461538461538462
# slk	0.5612244897959183
# slk	0.6853932584269663
# slk	0.6288659793814433
# slk	0.6893203883495146
# slk	0.44339622641509435
# slk	0.6224489795918368
# slk	0.6703296703296703
# slk	0.6808510638297872
# slk	0.7117117117117117
# slk	0.7372881355932204
# slk	0.8404255319148937
# slk	0.591304347826087
# slk	0.7127659574468085
# slk	0.9326923076923077
# slk	0.5773195876288659
# slk	0.580952380952381
# slk	0.7075471698113207
# slk	0.6666666666666666
# slk	0.6179775280898876
# slk	0.5196078431372549
# slk	0.5862068965517241
# slk	0.7692307692307693
# slk	0.5294117647058824
# slk	0.4857142857142857
# slk	0.5555555555555556
# slk	0.8672566371681416
# slk	0.6276595744680851
# slk	0.6862745098039216
# slk	0.6666666666666666
# slk	0.7916666666666666
# slk	0.5638297872340425
# slk	0.6952380952380952
# slk	0.6224489795918368
# slk	0.5648148148148148
# slk	0.6446280991735537
# slk	0.625
# slk	0.5882352941176471
# slk	0.6153846153846154
# slk	0.7211538461538461
# slk	0.6695652173913044
# slk	0.8089887640449438
# slk	0.7017543859649122
# slk	0.6890756302521008
# slk	0.8163265306122449
# slk	0.6434782608695652
# slk	0.5867768595041323
# slk	0.7884615384615384
# slk	0.7872340425531915
# slk	0.7102803738317757
# slk	0.7307692307692307
# slk	0.550561797752809
# slk	0.7469879518072289
# slk	0.6764705882352942
# slk	0.5225225225225225
# slk	0.6388888888888888
# slk	0.6702127659574468
# slk	0.6914893617021277
# slk	0.7207207207207207
# slk	0.6428571428571429
# slk	0.7083333333333334
# slk	0.9438202247191011
# slk	0.5730337078651685
# slk	0.7222222222222222
# slk	0.6086956521739131
# slk	0.9074074074074074
# slk	0.5816326530612245
# slk	0.7739130434782608
# slk	0.6119402985074627
# slk	0.5955056179775281
# slk	0.7676767676767676
# slk	0.6530612244897959
# slk	0.5730337078651685
# slk	0.711864406779661
# slk	0.6530612244897959
# slk	0.7303370786516854
# slk	0.71
# slk	0.7127659574468085
# slk	0.5576923076923077
# slk	0.7572815533980582
# slk	0.7361111111111112
# slk	0.6063829787234043
# slk	0.7222222222222222
# slk	0.6690647482014388
# slk	0.6739130434782609
# slk	0.6861313868613139
# slk	0.5694444444444444
# slk	0.6944444444444444
# slk	0.7288135593220338
# slk	0.9245283018867925
# slk	0.7078651685393258
# slk	0.8207547169811321
# slk	0.6067415730337079
# slk	0.8305084745762712
# slk	0.7010309278350515
# slk	0.6701030927835051
# slk	0.6228070175438597
# slk	0.7916666666666666
# slk	0.6388888888888888
# slk	0.5694444444444444
# slk	0.8376068376068376
# slk	0.6057692307692307
# slk	0.7252747252747253
# slk	0.5701754385964912
# slk	0.6666666666666666
# slk	0.8936170212765957
# slk	0.8715083798882681
# slk	0.6509433962264151
# slk	0.6346153846153846
# slk	0.7719298245614035
# slk	0.8240740740740741
# slk	0.5495495495495496
# slk	0.7127659574468085
# slk	0.7191011235955056
# slk	0.5943396226415094
# slk	0.7304347826086957
# slk	0.9722222222222222
# slk	0.6767676767676768
# slk	0.7777777777777778
# slk	0.875
# slk	0.7130434782608696
# slk	0.5555555555555556
# slk	0.7083333333333334
# slk	0.6836734693877551
# slk	0.6428571428571429
# slk	0.5909090909090909
# slk	0.7478260869565218
# slk	0.7472527472527473
# slk	0.8085106382978723
# slk	0.5769230769230769
# slk	0.7872340425531915
# slk	0.6206896551724138
# slk	0.7361111111111112
# slk	0.6276595744680851
# slk	0.8557692307692307
# slk	0.7361111111111112
# slk	0.7128712871287128
# slk	0.7752808988764045
# slk	0.6530612244897959
# slk	0.5972222222222222
# slk	0.8055555555555556
# slk	0.5531914893617021
# slk	0.679144385026738
# slk	0.6698113207547169
# slk	0.5862068965517241
# slk	0.9393939393939394
# slk	0.75
# slk	0.6966292134831461
# slk	0.5972222222222222
# slk	0.7216494845360825
# slk	0.7641509433962265
# slk	0.6527777777777778
# slk	0.9631578947368421
# slk	0.8235294117647058
# slk	0.7547169811320755
# slk	0.6153846153846154
# slk	0.6929133858267716
# slk	0.6063829787234043
# slk	0.6274509803921569
# slk	0.6292134831460674
# slk	0.6527777777777778
# slk	0.5258620689655172
# slk	0.5833333333333334
# slk	0.5972222222222222
# slk	0.5842696629213483
# slk	0.6666666666666666
# slk	0.7636363636363637
# slk	0.7222222222222222
# slk	0.5972222222222222
# slk	0.7659574468085106
# slk	0.5566037735849056
# slk	0.5625
# slk	0.6804123711340206
# slk	0.6896551724137931
# slk	0.7685185185185185
# slk	0.6808510638297872
# slk	0.9148936170212766
# slk	0.8426966292134831
# slk	0.6
# slk	0.6728971962616822
# slk	0.7821782178217822
# slk	0.5277777777777778
# slk	0.6732673267326733
# slk	0.75
# slk	0.7094017094017094
# slk	0.7264150943396226
# slk	0.7083333333333334
# slk	0.6805555555555556
# slk	0.7659574468085106
# slk	0.7361111111111112
# slk	0.4583333333333333
# slk	0.574468085106383
# slk	0.7391304347826086
# slk	0.5555555555555556
# slk	0.6886792452830188
# slk	0.582089552238806
# slk	0.7870370370370371
# slk	0.5903614457831325
# slk	0.5949367088607594
# slk	0.6146788990825688
# slk	0.7169811320754716
# slk	0.7340425531914894
# slk	0.7978723404255319
# slk	0.6764705882352942
# slk	0.7450980392156863
# slk	0.723404255319149
# slk	0.6144578313253012
# slk	0.8055555555555556
# slk	0.6805555555555556
# slk	0.4050632911392405
# slk	0.696078431372549
# slk	0.5869565217391305
# slk	0.6326530612244898
# slk	0.6527777777777778
# slk	0.8518518518518519
# slk	0.5210084033613446
# slk	0.49504950495049505
# slk	0.6037735849056604
# slk	0.5555555555555556
# slk	1.0
# slk	0.5730337078651685
# slk	0.6382978723404256
# slk	0.6542056074766355
# slk	0.8192771084337349
# slk	0.8415841584158416
# slk	0.7528089887640449
# slk	0.6805555555555556
# slk	0.65
# slk	0.9027777777777778
# slk	0.7640449438202247
# slk	0.6111111111111112
# slk	0.5421686746987951
# slk	0.6179775280898876
# slk	0.5769230769230769
# slk	0.7640449438202247
# slk	0.7058823529411765
# slk	0.7021276595744681
# slk	0.5443037974683544
# slk	0.660377358490566
# slk	0.7222222222222222
# slk	0.6372549019607843
# slk	0.42696629213483145
# slk	0.6831683168316832
# slk	0.7974683544303798
# slk	1.0
# slk	0.6153846153846154
# slk	0.7021276595744681
# slk	0.7307692307692307
# slk	0.875
# slk	0.625
# slk	0.5172413793103449
# slk	0.8556701030927835
# slk	0.7752808988764045
# slk	0.8725490196078431
# slk	0.6111111111111112
# slk	0.5769230769230769
# slk	0.625
# slk	0.6261682242990654
# slk	0.6632653061224489
# slk	0.7401574803149606
# slk	0.6914893617021277
# slk	0.8333333333333334
# slk	0.5233644859813084
# slk	0.6944444444444444
# slk	0.8846153846153846
# slk	0.8545454545454545
# slk	0.7361111111111112
# slk	0.8514851485148515
# slk	0.576271186440678
# slk	0.6741573033707865
# slk	0.7319587628865979
# slk	0.8269230769230769
# slk	0.7032967032967034
# slk	0.5842696629213483
# slk	0.6024096385542169
# slk	0.5949367088607594
# slk	0.900990099009901
# slk	0.6101694915254238
# slk	0.6814159292035398
# slk	0.6224489795918368
# slk	0.5972222222222222
# slk	0.782608695652174
# slk	0.7289719626168224
# slk	0.9607843137254902
# slk	0.86
# slk	0.7227722772277227
# slk	0.5555555555555556
# slk	0.5972222222222222
# slk	0.6593406593406593
# slk	0.6410256410256411
# slk	0.7029702970297029
# slk	0.6944444444444444
# slk	0.6842105263157895
# slk	0.6694915254237288
# slk	0.8712871287128713
# slk	0.6446280991735537
# slk	0.8314606741573034
# slk	0.7050359712230215
# slk	0.7525773195876289
# slk	0.651685393258427
# slk	0.7913043478260869
# slk	0.5046728971962616
# slk	0.979381443298969
# slk	0.6981132075471698
# slk	0.7452830188679245
# slk	0.6804123711340206
# slk	0.5555555555555556
# slk	0.6595744680851063
# slk	0.7714285714285715
# slk	0.7027027027027027
# slk	0.6391752577319587
# slk	0.5977011494252874
# slk	0.550561797752809
# slk	0.5851063829787234
# slk	0.651685393258427
# slk	0.6263736263736264
# slk	0.8611111111111112
# slk	0.7640449438202247
# slk	0.6024096385542169
# slk	0.5694444444444444
# slk	0.6388888888888888
# slk	0.6702127659574468
# slk	0.7745098039215687
# slk	0.7631578947368421
# slk	0.7761194029850746
# slk	0.6808510638297872
# slk	0.9213483146067416
# slk	0.6382978723404256
# slk	0.7222222222222222
# slk	0.7719298245614035
# slk	0.6336633663366337
# slk	0.7912087912087912
# slk	0.6263736263736264
# slk	0.6132075471698113
# slk	0.7980769230769231
# slk	0.63
# slk	0.7191011235955056
# slk	0.651685393258427
# slk	0.7452830188679245
# slk	0.5826086956521739
# slk	0.8723404255319149
# slk	0.8055555555555556
# slk	0.5876288659793815
# slk	0.5555555555555556
# slk	0.723404255319149
# slk	0.5959595959595959
# slk	0.5
# slk	0.7777777777777778
# slk	0.6288659793814433
# slk	0.5694444444444444
# slk	0.7777777777777778
# slk	0.7403846153846154
# slk	0.717948717948718
# slk	0.8584070796460177
# slk	0.7572815533980582
# slk	0.6237623762376238
# slk	0.9325842696629213
# slk	0.7647058823529411
# slk	0.6138613861386139
# slk	0.7980769230769231
# slk	0.8018867924528302
# slk	0.8363636363636363
# slk	0.7272727272727273
# slk	0.851063829787234
# slk	0.5490196078431373
# slk	0.6956521739130435
# slk	0.7128712871287128
# slk	0.7663551401869159
# slk	0.8194444444444444
# slk	0.7352941176470589
# slk	0.8061224489795918
# slk	0.5730337078651685
# slk	0.7211538461538461
# slk	0.5862068965517241
# slk	0.7391304347826086
# slk	0.8144329896907216
# slk	0.5138888888888888
# slk	0.7391304347826086
# slk	0.8545454545454545
# slk	0.5670103092783505
# slk	0.5979381443298969
# slk	0.6111111111111112
# slk	0.696969696969697
# slk	0.4473684210526316
# slk	0.5046728971962616
# slk	0.6440677966101694
# slk	0.8454545454545455
# slk	0.5972222222222222
# slk	0.5490196078431373
# slk	0.5
# slk	0.7872340425531915
# slk	0.5833333333333334
# slk	0.6632653061224489
# slk	0.6434782608695652
# slk	0.5217391304347826
# slk	0.5660377358490566
# slk	0.5074626865671642
# slk	0.6261682242990654
# slk	0.46846846846846846
# slk	0.5607476635514018
# slk	0.7884615384615384
# slk	0.6527777777777778
# slk	0.6702127659574468
# slk	0.7978723404255319
# slk	0.9065420560747663
# slk	0.7222222222222222
# slk	0.6732673267326733
# slk	0.6966292134831461
# slk	0.5408163265306123
# slk	0.7551020408163265
# slk	0.5694444444444444
# slk	0.8297872340425532
# slk	0.8611111111111112
# slk	0.6388888888888888
# slk	0.4626865671641791
# slk	0.5164835164835165
# slk	0.7142857142857143
# slk	0.5970149253731343
# slk	0.5833333333333334
# slk	0.7083333333333334
# slk	0.7909090909090909
# slk	0.6635514018691588
# slk	0.8472222222222222
# slk	0.6304347826086957
# slk	0.6186440677966102
# slk	0.5463917525773195
# slk	0.6805555555555556
# slk	0.6039603960396039
# slk	0.8508771929824561
# slk	0.8301886792452831
# slk	0.6111111111111112
# slk	0.6185567010309279
# slk	0.6527777777777778
# slk	0.56
# slk	0.7090909090909091
# slk	0.8194444444444444
# slk	0.5569620253164557
# slk	0.5
# slk	0.8173076923076923
# slk	0.6304347826086957
# slk	0.5742574257425742
# slk	0.8380952380952381
# slk	0.6111111111111112

# %%
results = []
for i in range(len(test_data)):
    results.append({'Language':data.loc[data['match_rate_lang_'+str(i)].idxmax()]['lang'], 'Score':data.loc[data['match_rate_lang_'+str(i)].idxmax()]['match_rate_lang_'+str(i)]})
res_df = pd.DataFrame(results)
res_df.head()
# Out:
#   Language     Score
# 0      slk  0.728972
# 1      slk  0.642857
# 2      slk  0.651685
# 3      slk  0.765306
# 4      slk  0.890909

# %%
res_df['Score'].groupby(res_df['Language']).mean()
# Out:
# Language
# slk    0.686813
# Name: Score, dtype: float64
