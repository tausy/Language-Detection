# %% [markdown]
# # Creation of Language Training Profiles

# %% [markdown]
# ## 1. Required Imports

# %%
import nltk
from nltk.tokenize import word_tokenize
import pandas as pd

# %% [markdown]
# ## 2. Read Wili-2018 Dataset and filter it for 34 European Languages

# %%
data = pd.read_csv('/Users/ashwinkumar/Desktop/MLProj/wili-2018/x_train.txt', sep='\r\n', header=None, engine='python')
res = pd.read_csv('/Users/ashwinkumar/Desktop/MLProj/wili-2018/y_train.txt', sep='\r\n', header=None, engine='python')
langs = ['slk']
#'nld','swe']
#,'tur','lat','dan','por','fra','bos','bul','gle','be-tarask','spa','isl','cym','srp','ita','fin','cat','ron','ces','rus','lit','sqi','slk','ukr','hrv','eng','mlt','hye','nno','hun','deu','mwl','pol','ell','ltz']
data['1'] = res
data.columns = ['text', 'lang']
data = data[data['lang'].isin(langs)].reset_index(drop=True)
data.head()
# Out:
#                                                 text lang
# 0  január 2000 – po voľbách sa časť poslancov zvo...  slk
# 1  Kniha obsahuje kompiláciu výrokov a rozhovorov...  slk
# 2  Waters bývalých spoluhráčov zažaloval za neopr...  slk
# 3  Třebovice je obec v Česku v okrese Ústí nad Or...  slk
# 4  Vydávala periodiká Časopis Muzeálnej slovenske...  slk

# %% [markdown]
# ## 3. Print filtered Lang Samples and Shape of Dataframe

# %%
print(data.head())
data.shape
# Out:
#                                                 text lang
# 0  január 2000 – po voľbách sa časť poslancov zvo...  slk
# 1  Kniha obsahuje kompiláciu výrokov a rozhovorov...  slk
# 2  Waters bývalých spoluhráčov zažaloval za neopr...  slk
# 3  Třebovice je obec v Česku v okrese Ústí nad Or...  slk
# 4  Vydávala periodiká Časopis Muzeálnej slovenske...  slk
# (500, 2)

# %% [markdown]
# ## 4. Preprocess Lang Data(Remove punctuations and digits)

# %%
data['text'] = data['text'].str.replace(r'[^\w\s]+', '')
data['text'] = data['text'].str.replace(r'[\d]+', '')
data['text'] = data['text'].astype(str).str.lower()
data.shape
# Out:
# (500, 2)

# %% [markdown]
# ## 4. Tokenize Lang Data to Prepare Lang Profiles

# %%
#data = data.groupby('lang')['text'].apply(' '.join).reset_index()
data['text'] = data.text.apply(word_tokenize)
data.shape
# Out:
# (500, 2)

# %% [markdown]
# ## 5. Function to Create N-GRAMS

# %%
def word2ngrams(text, n=1):
  """ Convert word into character ngrams. """
  return [text[i:i+n] for i in range(len(text)-n+1)]

# %% [markdown]
# ## 6. Generate Lang Profiles using Mono, Bi and Tri GRAMS

# %%
ngrams = []
data['ngrams'] = ''
for lang in data.text:
    lang_ngram = []
    for word in lang:
        lang_ngram = lang_ngram + word2ngrams(word,1) 
    lang_ngram = sorted(list(set(lang_ngram)), key=len)
    ngrams.append(lang_ngram)

for i in range(len(ngrams)):
    data.at[i, 'ngrams'] = ngrams[i]
data.shape
# Out:
# (500, 3)

# %%
data.head()
# Out:
#                                                 text lang  \
# 0  [január, po, voľbách, sa, časť, poslancov, zvo...  slk
# 1  [kniha, obsahuje, kompiláciu, výrokov, a, rozh...  slk
# 2  [waters, bývalých, spoluhráčov, zažaloval, za,...  slk
# 3  [třebovice, je, obec, v, česku, v, okrese, úst...  slk
# 4  [vydávala, periodiká, časopis, muzeálnej, slov...  slk
#
#                                               ngrams
# 0  [l, v, ž, k, n, á, a, ú, p, š, r, c, z, ť, m, ...
# 1  [l, v, ž, k, é, n, á, a, ú, p, š, r, c, z, m, ...
# 2  [l, v, ž, k, ä, é, n, á, a, ú, p, š, r, c, z, ...
# 3  [l, v, ž, k, n, á, a, ú, p, r, c, z, m, č, d, ...
# 4  [l, v, k, é, n, á, a, ú, p, r, z, m, č, d, e, ...

# %% [markdown]
# ## 7. Write Generated Lang Profiles in JSON

# %%
data.to_json('/Users/ashwinkumar/Desktop/MLProj/wili-2018/lang_profiles.json', orient='values')

# %% [markdown]
# # Detect Language using Test Language Profiles

# %% [markdown]
# ## 1. Load Test Data

# %%
test_data = pd.read_csv('/Users/ashwinkumar/Desktop/MLProj/wili-2018/x_test.txt', sep='\r\n', header=None, engine='python')
test_res = pd.read_csv('/Users/ashwinkumar/Desktop/MLProj/wili-2018/y_test.txt', sep='\r\n', header=None, engine='python')
test_langs = ['slk']
    #'swe','nld','tur','lat','dan','por','fra','bos','bul','gle','be-tarask','spa','isl','cym','srp','ita','fin','cat','ron','ces','rus','lit','sqi','slk','ukr','hrv','eng','mlt','hye','nno','hun','deu','mwl','pol','ell','ltz']
test_data['1'] = test_res
test_data.columns = ['text', 'lang']
test_data = test_data[test_data['lang'].isin(langs)].reset_index(drop=True)
test_data.head()
# Out:
#                                                 text lang
# 0  Podujal sa preto rozlúštiť tento paradox. Syst...  slk
# 1  V roku 2002 ho prezident George W. Bush vymeno...  slk
# 2  V hudbe sa za Underground označuje smer, ktorý...  slk
# 3  Do roku 1919 mladé talenty zo Slovenska navšte...  slk
# 4  George Hammond nastúpil ako generál v prvom di...  slk

# %% [markdown]
# ## 2. Print filtered Lang Test Samples and Shape of Dataframe

# %%
print(test_data.head())
test_data.shape
# Out:
#                                                 text lang
# 0  Podujal sa preto rozlúštiť tento paradox. Syst...  slk
# 1  V roku 2002 ho prezident George W. Bush vymeno...  slk
# 2  V hudbe sa za Underground označuje smer, ktorý...  slk
# 3  Do roku 1919 mladé talenty zo Slovenska navšte...  slk
# 4  George Hammond nastúpil ako generál v prvom di...  slk
# (500, 2)

# %% [markdown]
# ## 3. Preprocess Test Lang Data(Remove punctuations and digits)

# %%
test_data['text'] = test_data['text'].str.replace(r'[^\w\s]+', '')
test_data['text'] = test_data['text'].str.replace(r'[\d]+', '')
test_data['text'] = test_data['text'].astype(str).str.lower()
test_data.head()
# Out:
#                                                 text lang
# 0  podujal sa preto rozlúštiť tento paradox syste...  slk
# 1  v roku  ho prezident george w bush vymenoval d...  slk
# 2  v hudbe sa za underground označuje smer ktorý ...  slk
# 3  do roku  mladé talenty zo slovenska navštevova...  slk
# 4  george hammond nastúpil ako generál v prvom di...  slk

# %% [markdown]
# ## 4. Tokenize Test Lang Data to Prepare Lang Profiles

# %%
test_data['text'] = test_data.text.apply(word_tokenize)
test_data.head()
# Out:
#                                                 text lang
# 0  [podujal, sa, preto, rozlúštiť, tento, paradox...  slk
# 1  [v, roku, ho, prezident, george, w, bush, vyme...  slk
# 2  [v, hudbe, sa, za, underground, označuje, smer...  slk
# 3  [do, roku, mladé, talenty, zo, slovenska, navš...  slk
# 4  [george, hammond, nastúpil, ako, generál, v, p...  slk

# %% [markdown]
# ## 5. Generate Test Lang Profiles using Mono, Bi and Tri GRAMS

# %%
ngrams = []
test_data['ngrams'] = ''
for lang in test_data.text:
    lang_ngram = []
    for word in lang:
        lang_ngram = lang_ngram + word2ngrams(word,1) 
    lang_ngram = sorted(list(set(lang_ngram)), key=len)
    ngrams.append(lang_ngram)
#print(ngrams)
for i in range(len(ngrams)):
    test_data.at[i, 'ngrams'] = ngrams[i]
test_data.head()
# Out:
#                                                 text lang  \
# 0  [podujal, sa, preto, rozlúštiť, tento, paradox...  slk
# 1  [v, roku, ho, prezident, george, w, bush, vyme...  slk
# 2  [v, hudbe, sa, za, underground, označuje, smer...  slk
# 3  [do, roku, mladé, talenty, zo, slovenska, navš...  slk
# 4  [george, hammond, nastúpil, ako, generál, v, p...  slk
#
#                                               ngrams
# 0  [l, v, ž, k, n, á, a, ú, p, š, r, z, c, ť, m, ...
# 1  [l, v, k, é, n, á, a, ú, p, š, r, z, c, m, ť, ...
# 2  [l, v, ž, k, ä, é, n, á, a, p, š, r, z, c, m, ...
# 3  [l, v, ž, k, é, n, á, a, ú, p, š, r, z, c, m, ...
# 4  [l, v, ž, k, ä, é, n, á, a, ú, p, r, z, c, m, ...

# %%
test_data.shape
# Out:
# (500, 3)

# %%
print(data['ngrams'][0])
print(test_data['ngrams'][0])
# Out:
# ['l', 'v', 'ž', 'k', 'n', 'á', 'a', 'ú', 'p', 'š', 'r', 'c', 'z', 'ť', 'm', 'ô', 'č', 'd', 'e', 'j', 't', 'o', 'u', 'h', 'ý', 'í', 'i', 'b', 's', 'ľ']
# ['l', 'v', 'ž', 'k', 'n', 'á', 'a', 'ú', 'p', 'š', 'r', 'z', 'c', 'ť', 'm', 'č', 'd', 'e', 'j', 't', 'o', 'u', 'x', 'h', 'ý', 'í', 'i', 'y', 'b', 's', 'ľ']

# %%
data.shape
# Out:
# (500, 3)

# %%
UB = 0.95
LB = 0.92

for i in range(len(test_data)):
    for j in range(len(data)):
        data.at[j, 'match_rate_lang_'+str(i)] = len(set(test_data.iloc[i]['ngrams']).intersection(data.iloc[j]['ngrams']))/len(data.iloc[j]['ngrams'])
data.head()
# Out:
#                                                 text lang  \
# 0  [január, po, voľbách, sa, časť, poslancov, zvo...  slk
# 1  [kniha, obsahuje, kompiláciu, výrokov, a, rozh...  slk
# 2  [waters, bývalých, spoluhráčov, zažaloval, za,...  slk
# 3  [třebovice, je, obec, v, česku, v, okrese, úst...  slk
# 4  [vydávala, periodiká, časopis, muzeálnej, slov...  slk
#
#                                               ngrams  match_rate_lang_0  \
# 0  [l, v, ž, k, n, á, a, ú, p, š, r, c, z, ť, m, ...           0.966667
# 1  [l, v, ž, k, é, n, á, a, ú, p, š, r, c, z, m, ...           0.852941
# 2  [l, v, ž, k, ä, é, n, á, a, ú, p, š, r, c, z, ...           0.805556
# 3  [l, v, ž, k, n, á, a, ú, p, r, c, z, m, č, d, ...           0.965517
# 4  [l, v, k, é, n, á, a, ú, p, r, z, m, č, d, e, ...           0.961538
#
#    match_rate_lang_1  match_rate_lang_2  match_rate_lang_3  match_rate_lang_4  \
# 0           0.833333           0.900000           0.933333           0.933333
# 1           0.852941           0.882353           0.941176           0.941176
# 2           0.833333           0.861111           0.888889           0.944444
# 3           0.827586           0.931034           0.931034           0.931034
# 4           0.923077           0.961538           1.000000           1.000000
#
#    match_rate_lang_5  match_rate_lang_6         ...           \
# 0           0.833333           0.933333         ...
# 1           0.764706           0.852941         ...
# 2           0.722222           0.805556         ...
# 3           0.896552           0.931034         ...
# 4           0.884615           0.961538         ...
#
#    match_rate_lang_490  match_rate_lang_491  match_rate_lang_492  \
# 0             0.800000             0.933333             0.966667
# 1             0.823529             0.911765             0.970588
# 2             0.777778             0.861111             0.944444
# 3             0.758621             0.931034             0.965517
# 4             0.807692             1.000000             1.000000
#
#    match_rate_lang_493  match_rate_lang_494  match_rate_lang_495  \
# 0             0.833333             0.700000             0.966667
# 1             0.794118             0.735294             0.970588
# 2             0.777778             0.722222             0.972222
# 3             0.896552             0.724138             0.965517
# 4             1.000000             0.807692             1.000000
#
#    match_rate_lang_496  match_rate_lang_497  match_rate_lang_498  \
# 0             0.900000             0.766667             0.933333
# 1             0.852941             0.705882             0.911765
# 2             0.777778             0.666667             0.916667
# 3             0.896552             0.793103             0.965517
# 4             0.961538             0.846154             1.000000
#
#    match_rate_lang_499
# 0             0.866667
# 1             0.852941
# 2             0.805556
# 3             0.862069
# 4             0.923077
#
# [5 rows x 503 columns]

# %%
print('Language\tScore')
for i in range(len(test_data)):
    print(data.loc[data['match_rate_lang_'+str(i)].idxmax()]['lang']+'\t'+str(data.loc[data['match_rate_lang_'+str(i)].idxmax()]['match_rate_lang_'+str(i)]))
# Out:
# Language	Score
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	0.9629629629629629
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	0.9583333333333334
# slk	1.0
# slk	0.96
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	0.9259259259259259
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	0.9583333333333334
# slk	1.0
# slk	1.0
# slk	0.9655172413793104
# slk	1.0
# slk	1.0
# slk	1.0
# slk	0.9130434782608695
# slk	0.9166666666666666
# slk	1.0
# slk	1.0
# slk	0.9259259259259259
# slk	1.0
# slk	1.0
# slk	0.9666666666666667
# slk	0.9166666666666666
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	0.9583333333333334
# slk	1.0
# slk	0.9230769230769231
# slk	0.9629629629629629
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	0.9629629629629629
# slk	0.9642857142857143
# slk	1.0
# slk	1.0
# slk	0.9615384615384616
# slk	1.0
# slk	0.9615384615384616
# slk	1.0
# slk	0.9583333333333334
# slk	0.8461538461538461
# slk	0.9629629629629629
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	0.96
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	0.9615384615384616
# slk	1.0
# slk	0.9655172413793104
# slk	0.96875
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	0.9629629629629629
# slk	1.0
# slk	1.0
# slk	1.0
# slk	0.9642857142857143
# slk	1.0
# slk	0.9259259259259259
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	0.9629629629629629
# slk	0.9285714285714286
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	0.9642857142857143
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	0.9615384615384616
# slk	1.0
# slk	1.0
# slk	0.9565217391304348
# slk	1.0
# slk	1.0
# slk	1.0
# slk	0.9642857142857143
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	0.9642857142857143
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	0.9615384615384616
# slk	1.0
# slk	1.0
# slk	1.0
# slk	0.9629629629629629
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	0.9583333333333334
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	0.9259259259259259
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	0.9230769230769231
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	0.9629629629629629
# slk	1.0
# slk	1.0
# slk	0.9615384615384616
# slk	0.9615384615384616
# slk	1.0
# slk	1.0
# slk	0.9629629629629629
# slk	1.0
# slk	1.0
# slk	1.0
# slk	0.96
# slk	1.0
# slk	0.9583333333333334
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	0.9655172413793104
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	0.9666666666666667
# slk	1.0
# slk	1.0
# slk	1.0
# slk	0.8695652173913043
# slk	0.9130434782608695
# slk	1.0
# slk	0.9166666666666666
# slk	1.0
# slk	1.0
# slk	1.0
# slk	0.8846153846153846
# slk	0.8846153846153846
# slk	0.9629629629629629
# slk	0.9629629629629629
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	0.9666666666666667
# slk	1.0
# slk	1.0
# slk	0.8148148148148148
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	0.9259259259259259
# slk	0.96
# slk	0.9583333333333334
# slk	0.96
# slk	1.0
# slk	0.9583333333333334
# slk	1.0
# slk	1.0
# slk	0.9583333333333334
# slk	1.0
# slk	1.0
# slk	0.9655172413793104
# slk	0.96
# slk	1.0
# slk	1.0
# slk	0.9615384615384616
# slk	0.9642857142857143
# slk	1.0
# slk	0.9583333333333334
# slk	1.0
# slk	1.0
# slk	1.0
# slk	0.9615384615384616
# slk	1.0
# slk	1.0
# slk	1.0
# slk	0.7916666666666666
# slk	1.0
# slk	1.0
# slk	1.0
# slk	0.9230769230769231
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	0.9642857142857143
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	0.96
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	0.9230769230769231
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	0.9285714285714286
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	0.9166666666666666
# slk	0.9629629629629629
# slk	1.0
# slk	0.9285714285714286
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	0.9615384615384616
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	0.9583333333333334
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	0.875
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	0.9629629629629629
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	0.9655172413793104
# slk	0.9166666666666666
# slk	0.8928571428571429
# slk	1.0
# slk	0.9655172413793104
# slk	1.0
# slk	1.0
# slk	0.9166666666666666
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	0.9166666666666666
# slk	0.9655172413793104
# slk	1.0
# slk	0.9629629629629629
# slk	1.0
# slk	1.0
# slk	1.0
# slk	0.9583333333333334
# slk	1.0
# slk	1.0
# slk	1.0
# slk	0.9166666666666666
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	0.92
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	0.9642857142857143
# slk	1.0
# slk	1.0
# slk	1.0
# slk	0.9166666666666666
# slk	1.0
# slk	1.0
# slk	1.0
# slk	0.9285714285714286
# slk	0.9615384615384616
# slk	0.9629629629629629
# slk	1.0
# slk	0.9166666666666666
# slk	1.0
# slk	1.0
# slk	0.9629629629629629
# slk	1.0
# slk	0.9629629629629629
# slk	1.0
# slk	0.8260869565217391
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	0.9259259259259259
# slk	1.0
# slk	0.96
# slk	1.0
# slk	1.0
# slk	1.0
# slk	0.8888888888888888
# slk	0.88
# slk	1.0
# slk	0.9642857142857143
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	0.9655172413793104
# slk	1.0
# slk	1.0
# slk	1.0
# slk	1.0
# slk	0.9583333333333334
# slk	0.9629629629629629
# slk	1.0
# slk	0.8928571428571429
# slk	1.0
# slk	1.0
# slk	1.0
# slk	0.9130434782608695
# slk	1.0
# slk	1.0
# slk	0.8888888888888888
# slk	1.0
# slk	1.0

# %%
results = []
for i in range(len(test_data)):
    results.append({'Language':data.loc[data['match_rate_lang_'+str(i)].idxmax()]['lang'], 'Score':data.loc[data['match_rate_lang_'+str(i)].idxmax()]['match_rate_lang_'+str(i)]})
res_df = pd.DataFrame(results)
res_df.head()
# Out:
#   Language  Score
# 0      slk    1.0
# 1      slk    1.0
# 2      slk    1.0
# 3      slk    1.0
# 4      slk    1.0

# %%
res_df['Score'].groupby(res_df['Language']).mean()
# Out:
# Language
# slk    0.986601
# Name: Score, dtype: float64
